# %% [markdown]
# # Feature engineering
#
# Review the engineered study_engagement and absence_rate_proxy features and verify that target and leakage fields are excluded from X.
#
# This notebook is part of a reproducible project. Run from the repository root after `python scripts/train.py` and `python scripts/run_analysis.py`.

# %%
from pathlib import Path
import sys
import pandas as pd
ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(ROOT))
DATA = ROOT / 'data' / 'processed'
df = pd.read_csv(DATA / 'student_performance_clean.csv')
df.head()
